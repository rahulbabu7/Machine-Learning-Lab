# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([1,2,3,4,5])
ypoints= np.array([2,4,5,4,5])

# %%
plt.plot(xpoints,ypoints ,marker ="x")
plt.xlabel("independent")
plt.ylabel("dependent")
plt.grid()
